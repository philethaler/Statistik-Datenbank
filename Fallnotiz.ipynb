# %% [markdown]
# # Fallnotiz - Credit Card Transactions Dataset

# %% [markdown]
# **Notebook:** Analyse_1.ipynb
# **Datum:** 08.10.2025
# **Bearbeitet von:** …
# **Datensatz:** Kreditkarten-Transaktionen (Fraud Detection)
